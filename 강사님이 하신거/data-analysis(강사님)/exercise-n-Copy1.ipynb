# %%
import html
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
import requests
from bs4 import BeautifulSoup, NavigableString, Tag, Comment

# %%
from selenium import webdriver

driver_path = r"D:\bigdata-analysis\dev-tools\chromedriver.exe"
browser = webdriver.Chrome(executable_path=driver_path)

# %%
url = "https://news.naver.com/main/list.nhn"
query = "mode={0}&mid={1}&sid2={2}&sid1={3}&date={4}&page={5}"

page = 1
date = '20200702'

news_list = []

# if True:
for page in range(1, 5):
    time.sleep(0.3)
    current_url = "".join([url, "?", query]) \
                    .format("LS2D", "shm", "230", "105", date, page)

    browser.get(current_url)    
    soup = BeautifulSoup(browser.page_source, "html.parser")
    # print(soup)

    dl_list = soup.select("#main_content .list_body > ul > li > dl")
    
    if len(dl_list) == 0:
        pass
    
    for idx, dl in enumerate(dl_list):
        links = dl.select('dt > a')
        link = links[0] if len(links) == 1 else links[1]
        news_list.append( [link.text.strip(), link['href']])
# Out:
# 1
# 2
# 4- 0
# 4- 1
# 4- 2
# 4- 3
# 4- 4
# 4- 5
# 4- 6
# 4- 7
# 4- 8
# 4- 9
# 4- 10
# 4- 11
# 4- 12
# 4- 13
# 4- 14
# 4- 15
# 4- 16
# 4- 17
# 4- 18
# 4- 19
# 1
# 2
# 4- 0
# 4- 1
# 4- 2
# 4- 3
# 4- 4
# 4- 5
# 4- 6
# 4- 7
# 4- 8
# 4- 9
# 4- 10
# 4- 11
# 4- 12
# 4- 13
# 4- 14
# 4- 15
# 4- 16
# 4- 17
# 4- 18
# 4- 19
# 1
# 2
# 4- 0
# 4- 1
# 4- 2
# 4- 3
# 4- 4
# 4- 5
# 4- 6
# 4- 7
# 4- 8
# 4- 9
# 4- 10
# 4- 11
# 4- 12
# 4- 13
# 4- 14
# 4- 15
# 4- 16
# 4- 17
# 4- 18
# 4- 19
# 1
# 2
# 4- 0
# 4- 1
# 4- 2
# 4- 3
# 4- 4
# 4- 5
# 4- 6
# 4- 7
# 4- 8
# 4- 9
# 4- 10
# 4- 11
# 4- 12
# 4- 13
# 4- 14
# 4- 15
# 4- 16
# 4- 17
# 4- 18
# 4- 19

# %%
len(news_list)
# Out:
# 20

# %%
for news in news_list:
    
    time.sleep(0.3)

    link2 = news[1]
    browser.get(link2)
    soup2 = BeautifulSoup(browser.page_source, 'html.parser')

    contents = soup2.select_one('div#articleBodyContents')
    content_string = ""
    for child in contents.children:
        # print(child, '/', type(child))
        if type(child) == Tag and child.name != "script":
            content_string += child.text.strip() + " "
        if type(child) == NavigableString:
            content_string += str(child).strip() + " "
    
    # print(content_string)
    news.append(content_string) # [제목,주소] -> [제목,주소,내용]

# %%
browser.close()

# %%
# news_list[:3]
news_list_df = \
    pd.DataFrame(news_list, columns=['제목', '링크', '내용'])

# %%
news_list_df
# Out:
#                                               제목  \
# 0     “포스트 석유시대 이끌 원동력은 우주”…UAE, 15일 화성에 탐사선 보낸다
# 1                   광주 확진자 이틀째 최다… 비수도권 집단 감염 비상
# 2            삼성·준법위, 22일 워크숍…"위원회 활동·준법체계 의견 공유"
# 3            삼성준법감시위, 컴플라이언스 팀과 워크숍···준법체계 의견 공유
# 4         성착취물 공유 땐 카톡 영원히 못 쓴다…카카오 “아동 성범죄 무관용”
# ..                                           ...
# 75                 포스트 코로나 시대 여름휴가 키워드는 `제주·렌터카`
# 76  위세아이텍,교육부 `AI-매칭 성인학습자 교육과정 추천 시스템 구축` 사업 수주
# 77            카카오, 클라우드 시장에 첫발…"10년의 데이터 노하우 집약"
# 78  탑버스폰, 갤럭시S20 BTS 에디션 사전예약 시작, 노트9,노트10 특판 실시
# 79               LG유플러스 대전사옥서 코로나19 확진자 발생… 사옥폐쇄
#
#                                                    링크  \
# 0   https://news.naver.com/main/read.nhn?mode=LS2D...
# 1   https://news.naver.com/main/read.nhn?mode=LS2D...
# 2   https://news.naver.com/main/read.nhn?mode=LS2D...
# 3   https://news.naver.com/main/read.nhn?mode=LS2D...
# 4   https://news.naver.com/main/read.nhn?mode=LS2D...
# ..                                                ...
# 75  https://news.naver.com/main/read.nhn?mode=LS2D...
# 76  https://news.naver.com/main/read.nhn?mode=LS2D...
# 77  https://news.naver.com/main/read.nhn?mode=LS2D...
# 78  https://news.naver.com/main/read.nhn?mode=LS2D...
# 79  https://news.naver.com/main/read.nhn?mode=LS2D...
#
#                                                    내용
# 0        EMM 제공 “아랍에미리트( UAE ) 정부가 2014년 화성 탐사 프로젝...
# 1        신규 54명 중 22명, 누적 81명집단시설서 발생, 확산 가속화   코로...
# 2        "이재용 부회장 대국민 입장문은 중장기로 점검" (지디넷코리아=이은정  기...
# 3       삼성준법감시위원회는 2일 정기회의를 열고 위원회와 관계사 컴플라이언스 팀 간...
# 4           카카오가 2일부터 아동·청소년 대상 성범죄에 대해 강화된 규정을 적용...
# ..                                                ...
# 75       스카이스캐너, 여름휴가 여행 트렌드 분석   [사진 제공 = 스카이스캐너]...
# 76       인공지능친화적 교육환경기대   머신러닝 전문기업 위세아이텍이과학기술정보통신...
# 77       개발 환경, 앱 엔진, AI 등 서비스 제공…"데이터센터 구축도 검토"  ...
# 78        삼성전자가 선보인 '갤럭시S20 BTS 에디션'과 '갤럭시버즈 플러스 B...
# 79       LG유플러스 대전오류사옥에서 코로나19 확진자가 나왔다. /사진=뉴스1 L...
#
# [80 rows x 3 columns]
