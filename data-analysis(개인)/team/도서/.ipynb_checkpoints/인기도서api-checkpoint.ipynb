# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import lxml

# %%
api_key = 'e90824929c90f865d4233fa27e08262b1abfb5c4e60b98ba85fc70f5d6d695e9'
api_url = 'http://data4library.kr/api/loanItemSrch?'

parms = 'authKey={api_key}&' + \
        'startDt={startDt}&' + \
        'from_age={from_age}&' + \
        'region=11&'+ \
        'addCode=0;1;2;4;5;6;7;9&'+ \
        'pageNo=1&' +\
        'pageSize={size}'

url = api_url+ parms
print(url)
startDt='2020-01-01'
from_age='1'
size='500'
new_url = url.format(startDt=startDt, from_age=from_age, api_key=api_key , size=size)
print(new_url)

# resp = requests.get(url.format(startDt=startDt, from_age=from_age, api_key=api_key , size=size)
# soup = BeautifulSoup(new_url.text, 'html.parser')

# resp
# trs = soup.select()

# &startDt=2017-01-01   (시작날짜설정 끝날짜는 자동으로 하루 전날로 설정됨.)
# # &gender=0 (성별)  (미입력시 전체 , 0=남성 1=여성 2=미상)
# &from_age=6 (시작연령)
# &region=11 (지역)
# &addCode=0;1;2;4;5;6;7;9 (ISBN 부가기호)
# # &kdc=6
# # &pageNo=1  (페이지번호(pageNo) 미입력시 1로 설정 )
# &pageSize=100
# Out:
# http://data4library.kr/api/loanItemSrch?authKey={api_key}&startDt={startDt}&from_age={from_age}&region=11&addCode=0;1;2;4;5;6;7;9&pageNo=1&pageSize={size}
# http://data4library.kr/api/loanItemSrch?authKey=e90824929c90f865d4233fa27e08262b1abfb5c4e60b98ba85fc70f5d6d695e9&startDt=2020-01-01&from_age=1&region=11&addCode=0;1;2;4;5;6;7;9&pageNo=1&pageSize=500

# %%
req = requests.get(url.format(startDt=startDt, from_age=from_age, api_key=api_key , size=size))
req.status_code, req.encoding, req.text
# Out:
# (200,
#  'utf-8',
#  '<?xml version="1.0" encoding="UTF-8" standalone="no"?><response><request><startDt>2020-01-01</startDt><from_age>1</from_age><addCode>0;1;2;4;5;6;7;9</addCode><region>11</region><pageNo>1</pageNo><pageSize>500</pageSize></request><resultNum>500</resultNum><docs><doc><no>1</no><ranking>1</ranking><bookname><![CDATA[ 여행의 이유 :김영하 산문]]></bookname><authors><![CDATA[ 지은이: 김영하]]></authors><publisher><![CDATA[ 문학동네]]></publisher><publication_year><![CDATA[ 2019]]></publication_year><isbn13><![CDATA[ 9788954655972]]></isbn13><addition_symbol><![CDATA[ 03810]]></addition_symbol><vol/><class_no><![CDATA[ 816.7]]></class_no><loan_count>1,682</loan_count><bookImageURL><![CDATA[ https://image.aladin.co.kr/product/18827/60/cover/8954655971_2.jpg]]></bookImageURL></doc><doc><no>2</no><ranking>2</ranking><bookname><![CDATA[ 나미야 잡화점의 기적 :히가시노 게이고 장편소설]]></bookname><authors><![CDATA[ 지은이: 히가시노 게이고 ;옮긴이: 양윤옥]]></authors><publisher><![CDATA[ 현대문학]]></publisher><publication_year><![CDATA[ 2012]]></publication_year><isbn13><![CDATA[ 9788972756194]]></isbn13><addition_symbol><![CDATA[ 03830]]></addition_symbol><vol/><class_no><![CDATA[ 833.6]]></class_no><loan_count>1,613</loan_count><bookImageURL><![CDATA[ http://image.aladin.co.kr/product/15848/6/cover/k622533431_1.jpg]]></bookImageURL></doc><doc><no>3</no><ranking>3</ranking><bookname><![CDATA[ 82년생 김지영 :조남주 장편소설]]></bookname><authors><![CDATA[ 지은이: 조남주]]></authors><publisher><![CDATA[ 민음사]]></publisher><publication_year><![CDATA[ 2016]]></publication_year><isbn13><![CDATA[ 9788937473135]]></isbn13><addition_symbol><![CDATA[ 04810]]></addition_symbol><vol/><class_no><![CDATA[ 813.7]]></class_no><loan_count>1,563</loan_count><bookImageURL><![CDATA[ https://bookthumb-phinf.pstatic.net/cover/112/111/11211133.jpg?type=m1&udate=20180530]]></bookImageURL></doc><doc><no>4</no><ranking>4</ranking><bookname><![CDATA[ (추리 천재) 엉덩이 탐정]]></bookname><authors><![CDATA[ 트롤 글·그림 ;김정화 옮김]]></authors><publisher><![CDATA[ 미래엔]]></publisher><publication_year/><isbn13><![CDATA[ 9791162339466]]></isbn13><addition_symbol><![CDATA[ 74830]]></addition_symbol><vol><![CDATA[ 7]]></vol><class_no><![CDATA[ 833.6]]></class_no><loan_count>1,426</loan_count><bookImageURL><![CDATA[ https://image.aladin.co.kr/product/17457/14/cover/k792534209_1.jpg]]></bookImageURL></doc><doc><no>5</no><ranking>5</ranking><bookname><![CDATA[ (추리 천재) 엉덩이 탐정]]></bookname><authors><![CDATA[ 트롤 글·그림 ;김정화 옮김]]></authors><publisher><![CDATA[ 미래엔]]></publisher><publication_year/><isbn13><![CDATA[ 9791164131914]]></isbn13><addition_symbol><![CDATA[ 74830]]></addition_symbol><vol><![CDATA[ 8]]></vol><class_no><![CDATA[ 833.6]]></class_no><loan_count>1,398</loan_count><bookImageURL><![CDATA[ https://image.aladin.co.kr/product/19874/27/cover/k432635431_1.jpg]]></bookImageURL></doc><doc><no>6</no><ranking>6</ranking><bookname><![CDATA[ (추리 천재) 엉덩이 탐정]]></bookname><authors><![CDATA[ 트롤 글·그림 ;김정화 옮김]]></authors><publisher><![CDATA[ 미래엔]]></publisher><publication_year/><isbn13><![CDATA[ 9788937853470]]></isbn13><addition_symbol><![CDATA[ 74830]]></addition_symbol><vol><![CDATA[ 2]]></vol><class_no><![CDATA[ 833.6]]></class_no><loan_count>1,344</loan_count><bookImageURL><![CDATA[ https://bookthumb-phinf.pstatic.net/cover/113/327/11332741.jpg?type=m1&udate=20161209]]></bookImageURL></doc><doc><no>7</no><ranking>7</ranking><bookname><![CDATA[ (추리 천재) 엉덩이 탐정]]></bookname><authors><![CDATA[ 트롤 글·그림 ;김정화 옮김]]></authors><publisher><![CDATA[ 미래엔]]></publisher><publication_year/><isbn13><![CDATA[ 9788937848247]]></isbn13><addition_symbol><![CDATA[ 74830]]></addition_symbol><vol><![CDATA[ 4]]></vol><class_no><![CDATA[ 833.6]]></class_no><loan_count>1,328</loan_count><bookImageURL><![CDATA[ https://bookthumb-phinf.pstatic.net/cover/124/953/12495377.jpg?type=m1&udate=20170829]]></bookImageURL></doc><doc><no>8</no><ranking>8</ranking><bookname><![CDATA[ 선량한 차별주의자]]></bookname><authors><![CDATA[ 김지혜 지음]]></authors><publisher><![CDATA[ 창비]]></publisher><publication_year><![CDA ...

# %%
# 전체 문서에서 CDATA -> PCDATA 로 변경 replace
req2 = req.text.replace('<![CDATA[',' ')
req2pcdata = req2.replace(']]>',' ')
req2pcdata
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="no"?><response><request><startDt>2020-01-01</startDt><from_age>1</from_age><addCode>0;1;2;4;5;6;7;9</addCode><region>11</region><pageNo>1</pageNo><pageSize>500</pageSize></request><resultNum>500</resultNum><docs><doc><no>1</no><ranking>1</ranking><bookname>  여행의 이유 :김영하 산문 </bookname><authors>  지은이: 김영하 </authors><publisher>  문학동네 </publisher><publication_year>  2019 </publication_year><isbn13>  9788954655972 </isbn13><addition_symbol>  03810 </addition_symbol><vol/><class_no>  816.7 </class_no><loan_count>1,682</loan_count><bookImageURL>  https://image.aladin.co.kr/product/18827/60/cover/8954655971_2.jpg </bookImageURL></doc><doc><no>2</no><ranking>2</ranking><bookname>  나미야 잡화점의 기적 :히가시노 게이고 장편소설 </bookname><authors>  지은이: 히가시노 게이고 ;옮긴이: 양윤옥 </authors><publisher>  현대문학 </publisher><publication_year>  2012 </publication_year><isbn13>  9788972756194 </isbn13><addition_symbol>  03830 </addition_symbol><vol/><class_no>  833.6 </class_no><loan_count>1,613</loan_count><bookImageURL>  http://image.aladin.co.kr/product/15848/6/cover/k622533431_1.jpg </bookImageURL></doc><doc><no>3</no><ranking>3</ranking><bookname>  82년생 김지영 :조남주 장편소설 </bookname><authors>  지은이: 조남주 </authors><publisher>  민음사 </publisher><publication_year>  2016 </publication_year><isbn13>  9788937473135 </isbn13><addition_symbol>  04810 </addition_symbol><vol/><class_no>  813.7 </class_no><loan_count>1,563</loan_count><bookImageURL>  https://bookthumb-phinf.pstatic.net/cover/112/111/11211133.jpg?type=m1&udate=20180530 </bookImageURL></doc><doc><no>4</no><ranking>4</ranking><bookname>  (추리 천재) 엉덩이 탐정 </bookname><authors>  트롤 글·그림 ;김정화 옮김 </authors><publisher>  미래엔 </publisher><publication_year/><isbn13>  9791162339466 </isbn13><addition_symbol>  74830 </addition_symbol><vol>  7 </vol><class_no>  833.6 </class_no><loan_count>1,426</loan_count><bookImageURL>  https://image.aladin.co.kr/product/17457/14/cover/k792534209_1.jpg </bookImageURL></doc><doc><no>5</no><ranking>5</ranking><bookname>  (추리 천재) 엉덩이 탐정 </bookname><authors>  트롤 글·그림 ;김정화 옮김 </authors><publisher>  미래엔 </publisher><publication_year/><isbn13>  9791164131914 </isbn13><addition_symbol>  74830 </addition_symbol><vol>  8 </vol><class_no>  833.6 </class_no><loan_count>1,398</loan_count><bookImageURL>  https://image.aladin.co.kr/product/19874/27/cover/k432635431_1.jpg </bookImageURL></doc><doc><no>6</no><ranking>6</ranking><bookname>  (추리 천재) 엉덩이 탐정 </bookname><authors>  트롤 글·그림 ;김정화 옮김 </authors><publisher>  미래엔 </publisher><publication_year/><isbn13>  9788937853470 </isbn13><addition_symbol>  74830 </addition_symbol><vol>  2 </vol><class_no>  833.6 </class_no><loan_count>1,344</loan_count><bookImageURL>  https://bookthumb-phinf.pstatic.net/cover/113/327/11332741.jpg?type=m1&udate=20161209 </bookImageURL></doc><doc><no>7</no><ranking>7</ranking><bookname>  (추리 천재) 엉덩이 탐정 </bookname><authors>  트롤 글·그림 ;김정화 옮김 </authors><publisher>  미래엔 </publisher><publication_year/><isbn13>  9788937848247 </isbn13><addition_symbol>  74830 </addition_symbol><vol>  4 </vol><class_no>  833.6 </class_no><loan_count>1,328</loan_count><bookImageURL>  https://bookthumb-phinf.pstatic.net/cover/124/953/12495377.jpg?type=m1&udate=20170829 </bookImageURL></doc><doc><no>8</no><ranking>8</ranking><bookname>  선량한 차별주의자 </bookname><authors>  김지혜 지음 </authors><publisher>  창비 </publisher><publication_year>  2019 </publication_year><isbn13>  9788936477196 </isbn13><addition_symbol>  03300 </addition_symbol><vol/><class_no>  334 </class_no><loan_count>1,325</loan_count><bookImageURL>  https://image.aladin.co.kr/product/19874/76/cover/8936477196_1.jpg </bookImageURL></doc><doc><no>9</no><ranking>9</ranking><bookname>  사피엔스 :유인원에서 사이보그까지, 인간 역사의 대담하고 위대한 질문 </bookname><authors>  지은이: 유발 하라리 ;옮긴이: 조현욱 </authors><publisher>  김영사 </publisher><publication_year>  2015 </publication_year><isbn13>  9788934972464 </isbn13><addition_symbol>  03900 </addition_symbol><vol/><class_no>  909 </class_no><loan_ ...

# %%
soup = BeautifulSoup(req2pcdata, 'lxml')
# soup

# %%
docs = soup.select('doc')
# rank = soup.select('docs > doc > ranking')
# bookname = soup.select('docs > doc > bookname')

loanItem=[]
for doc in docs[:]:
 # print(doc.text)
  rank = doc.select_one('ranking')
  bookname = doc.select_one('bookname')
  authors = doc.select_one('authors')
  publisher = doc.select_one('publisher')
  isbn = doc.select_one('isbn13')
  count = doc.select_one('loan_count')

  loanItem.append([rank, bookname, authors, publisher, isbn, count])

# print(loanItem[0])

# columns=['순위','책이름','작가','출판사','ISBN',"대출건수"]
# loanItem_df = pd.DataFrame(loanItem, columns=columns)
# loanItem_df

# %%
import pickle
loanltem=['loanltem']

with open('loanltem','wb') as fw:
  pickle.dump(loanltem, fw)

with open('loanltem', 'rb') as f:
  loanltem = pickle.load(f)

print(loanItem)
# Out:
# [[<ranking>1</ranking>, <bookname>  여행의 이유 :김영하 산문 </bookname>, <authors>  지은이: 김영하 </authors>, <publisher>  문학동네 </publisher>, <isbn13>  9788954655972 </isbn13>, <loan_count>1,682</loan_count>], [<ranking>2</ranking>, <bookname>  나미야 잡화점의 기적 :히가시노 게이고 장편소설 </bookname>, <authors>  지은이: 히가시노 게이고 ;옮긴이: 양윤옥 </authors>, <publisher>  현대문학 </publisher>, <isbn13>  9788972756194 </isbn13>, <loan_count>1,613</loan_count>], [<ranking>3</ranking>, <bookname>  82년생 김지영 :조남주 장편소설 </bookname>, <authors>  지은이: 조남주 </authors>, <publisher>  민음사 </publisher>, <isbn13>  9788937473135 </isbn13>, <loan_count>1,563</loan_count>], [<ranking>4</ranking>, <bookname>  (추리 천재) 엉덩이 탐정 </bookname>, <authors>  트롤 글·그림 ;김정화 옮김 </authors>, <publisher>  미래엔 </publisher>, <isbn13>  9791162339466 </isbn13>, <loan_count>1,426</loan_count>], [<ranking>5</ranking>, <bookname>  (추리 천재) 엉덩이 탐정 </bookname>, <authors>  트롤 글·그림 ;김정화 옮김 </authors>, <publisher>  미래엔 </publisher>, <isbn13>  9791164131914 </isbn13>, <loan_count>1,398</loan_count>], [<ranking>6</ranking>, <bookname>  (추리 천재) 엉덩이 탐정 </bookname>, <authors>  트롤 글·그림 ;김정화 옮김 </authors>, <publisher>  미래엔 </publisher>, <isbn13>  9788937853470 </isbn13>, <loan_count>1,344</loan_count>], [<ranking>7</ranking>, <bookname>  (추리 천재) 엉덩이 탐정 </bookname>, <authors>  트롤 글·그림 ;김정화 옮김 </authors>, <publisher>  미래엔 </publisher>, <isbn13>  9788937848247 </isbn13>, <loan_count>1,328</loan_count>], [<ranking>8</ranking>, <bookname>  선량한 차별주의자 </bookname>, <authors>  김지혜 지음 </authors>, <publisher>  창비 </publisher>, <isbn13>  9788936477196 </isbn13>, <loan_count>1,325</loan_count>], [<ranking>9</ranking>, <bookname>  사피엔스 :유인원에서 사이보그까지, 인간 역사의 대담하고 위대한 질문 </bookname>, <authors>  지은이: 유발 하라리 ;옮긴이: 조현욱 </authors>, <publisher>  김영사 </publisher>, <isbn13>  9788934972464 </isbn13>, <loan_count>1,295</loan_count>], [<ranking>10</ranking>, <bookname>  (간단함, 병맛, 솔직함으로 기업의 흥망성쇠를 좌우하는) 90년생이 온다 </bookname>, <authors>  임홍택 지음 </authors>, <publisher>  Whale Books(웨일북) </publisher>, <isbn13>  9791188248674 </isbn13>, <loan_count>1,259</loan_count>], [<ranking>11</ranking>, <bookname>  (추리 천재) 엉덩이 탐정 </bookname>, <authors>  트롤 글·그림 ;김정화 옮김 </authors>, <publisher>  미래엔 </publisher>, <isbn13>  9788937889714 </isbn13>, <loan_count>1,248</loan_count>], [<ranking>12</ranking>, <bookname>  돌이킬 수 없는 약속 :야쿠마루 가쿠 장편소설 </bookname>, <authors>  저자: 야쿠마루 가쿠 ;옮긴이: 김성미 </authors>, <publisher>  Book plaza(북플라자) </publisher>, <isbn13>  9788998274795 </isbn13>, <loan_count>1,241</loan_count>], [<ranking>13</ranking>, <bookname>  나는 나로 살기로 했다 :냉담한 현실에서 어른살이를 위한 to do list </bookname>, <authors>  글·그림: 김수현 </authors>, <publisher>  마음의숲 </publisher>, <isbn13>  9791187119845 </isbn13>, <loan_count>1,198</loan_count>], [<ranking>14</ranking>, <bookname>  (추리 천재) 엉덩이 탐정 </bookname>, <authors>  트롤 글·그림 ;김정화 옮김 </authors>, <publisher>  미래엔 </publisher>, <isbn13>  9788937838750 </isbn13>, <loan_count>1,195</loan_count>], [<ranking>15</ranking>, <bookname>  언어의 온도 :말과 글에는 나름의 따뜻함과 차가움이 있다 </bookname>, <authors>  지은이: 이기주 </authors>, <publisher>  말글터 </publisher>, <isbn13>  9791195522125 </isbn13>, <loan_count>1,194</loan_count>], [<ranking>15</ranking>, <bookname>  공부머리 독서법 :실현 가능하고 지속 가능한 독서교육의 모든 것 </bookname>, <authors>  최승필 지음 </authors>, <publisher>  책구루 </publisher>, <isbn13>  9791196316808 </isbn13>, <loan_count>1,194</loan_count>], [<ranking>17</ranking>, <bookname>  팩트풀니스 :우리가 세상을 오해하는 10가지 이유와 세상이 생각보다 괜찮은 이유 </bookname>, <authors>  지은이: 한스 로슬링,옮긴이: 이창신 </authors>, <publisher>  김영사 </publisher>, <isbn13>  9788934985068 </isbn13>, <loan_count>1,133</loan_count>], [<ranking>18</ranking>, <bookname>  채식주의자:한강 연작소설 </bookname>, <authors>  한강 </authors>, <publisher>  창비 </publisher>, <isbn13>  9788936433598 </isbn13>, <loan_count>1,114</loan_count>], [<ranking>19</ranking>, <bookname>  당신이 옳다 :정혜신의 적정심리학 </bookname>, <authors>  지은이: 정혜신 </authors>, <publisher>  해냄 </publisher>, <isbn13>  9788965746669 </isbn13>, <loan_count>1,103</loan_count>], [<ranking>20</ranking> ...
