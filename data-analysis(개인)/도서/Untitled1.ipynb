# %%
import pickle

# %%
with open('col2dict.pickle','rb') as fr:
    data = pickle.load(fr)
    
columns = list(data['trd_pred_flpop'].keys())
columns

# with open('ckeck_col_dup (1).pickle','rb') as fr:
#     data1 = pickle.load(fr)
# data1
# ' creat table trd_pred_flpop (' +'')'
# Out:
# ['STDR_YY_CD',
#  'STDR_QU_CD',
#  'TRDAR_SE_CD',
#  'TRDAR_SE_CD_NM',
#  'TRDAR_CD',
#  'TRDAR_CD_NM',
#  'TOT_FLPOP_CO',
#  'ML_FLPOP_CO',
#  'FML_FLPOP_CO',
#  'AGRDE_10_FLPOP_CO',
#  'AGRDE_20_FLPOP_CO',
#  'AGRDE_30_FLPOP_CO',
#  'AGRDE_40_FLPOP_CO',
#  'AGRDE_50_FLPOP_CO',
#  'AGRDE_60_ABOVE_FLPOP_CO',
#  'TMZON_1_FLPOP_CO',
#  'TMZON_2_FLPOP_CO',
#  'TMZON_3_FLPOP_CO',
#  'TMZON_4_FLPOP_CO',
#  'TMZON_5_FLPOP_CO',
#  'TMZON_6_FLPOP_CO',
#  'MON_FLPOP_CO',
#  'TUES_FLPOP_CO',
#  'WED_FLPOP_CO',
#  'THUR_FLPOP_CO',
#  'FRI_FLPOP_CO',
#  'SAT_FLPOP_CO',
#  'SUN_FLPOP_CO',
#  'MAG_10_MONTM_1_FLPOP_CO',
#  'MAG_10_MONTM_2_FLPOP_CO',
#  'MAG_10_MONTM_3_FLPOP_CO',
#  'MAG_10_MONTM_4_FLPOP_CO',
#  'MAG_10_MONTM_5_FLPOP_CO',
#  'MAG_10_MONTM_6_FLPOP_CO',
#  'MAG_10_TUETM_1_FLPOP_CO',
#  'MAG_10_TUETM_2_FLPOP_CO',
#  'MAG_10_TUETM_3_FLPOP_CO',
#  'MAG_10_TUETM_4_FLPOP_CO',
#  'MAG_10_TUETM_5_FLPOP_CO',
#  'MAG_10_TUETM_6_FLPOP_CO',
#  'MAG_10_WEDTM_1_FLPOP_CO',
# ...
